# %%
from preprocess_SVD import * 
import matplotlib.pyplot as plt
import time

# %%
dataset = DatasetSVD()

# %%
dataset.compare_reconstruction(1, k=400)
# Out:
# Reconstruction time for k=400: 0.0066 seconds
