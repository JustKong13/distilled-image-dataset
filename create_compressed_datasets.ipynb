# %%
from preprocess_SVD import * 
import matplotlib.pyplot as plt
import time 

dataset = DatasetSVD(fft=False)

def create_dataset(singular_values): 
    original, fully_reconstructed, partially_reconstructed = dataset.compare_reconstruction(1, k=singular_values)
    dir = f"./CompressedDatasets/cifar/cifar10_{singular_values}"
    dataset.save(path=dir, k=singular_values)

X_train, y_train, X_test, y_test = dataset.X_train, dataset.y_train, dataset.X_test, dataset.y_test

np.savez(f"./CompressedDatasets/cifar/dataset.npz", X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

for i in range(200, 3072, 100): 
    print(f"Creating dataset with {i} singular values")
    start = time.time()
    create_dataset(i)
    end = time.time()
    print(f"Time taken: {end - start} seconds")
# Out:
# Creating dataset with 200 singular values
# Reconstruction time for k=200: 0.0039 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_200
# Time taken: 0.1983957290649414 seconds
# Creating dataset with 300 singular values
# Reconstruction time for k=300: 0.0026 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_300
# Time taken: 0.21532416343688965 seconds
# Creating dataset with 400 singular values
# Reconstruction time for k=400: 0.0049 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_400
# Time taken: 0.19155097007751465 seconds
# Creating dataset with 500 singular values
# Reconstruction time for k=500: 0.0072 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_500
# Time taken: 0.20121502876281738 seconds
# Creating dataset with 600 singular values
# Reconstruction time for k=600: 0.0111 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_600
# Time taken: 0.21948027610778809 seconds
# Creating dataset with 700 singular values
# Reconstruction time for k=700: 0.0081 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_700
# Time taken: 0.2541837692260742 seconds
# Creating dataset with 800 singular values
# Reconstruction time for k=800: 0.0128 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_800
# Time taken: 0.240401029586792 seconds
# Creating dataset with 900 singular values
# Reconstruction time for k=900: 0.0145 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_900
# Time taken: 0.280285120010376 seconds
# Creating dataset with 1000 singular values
# Reconstruction time for k=1000: 0.0216 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1000
# Time taken: 0.2933487892150879 seconds
# Creating dataset with 1100 singular values
# Reconstruction time for k=1100: 0.0279 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1100
# Time taken: 0.30261993408203125 seconds
# Creating dataset with 1200 singular values
# Reconstruction time for k=1200: 0.0297 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1200
# Time taken: 0.28220701217651367 seconds
# Creating dataset with 1300 singular values
# Reconstruction time for k=1300: 0.0317 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1300
# Time taken: 0.29488492012023926 seconds
# Creating dataset with 1400 singular values
# Reconstruction time for k=1400: 0.0338 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1400
# Time taken: 0.3004648685455322 seconds
# Creating dataset with 1500 singular values
# Reconstruction time for k=1500: 0.0375 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1500
# Time taken: 0.3261222839355469 seconds
# Creating dataset with 1600 singular values
# Reconstruction time for k=1600: 0.0417 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1600
# Time taken: 0.31531286239624023 seconds
# Creating dataset with 1700 singular values
# Reconstruction time for k=1700: 0.0448 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1700
# Time taken: 0.2950577735900879 seconds
# Creating dataset with 1800 singular values
# Reconstruction time for k=1800: 0.0417 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1800
# Time taken: 0.3382589817047119 seconds
# Creating dataset with 1900 singular values
# Reconstruction time for k=1900: 0.0584 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_1900
# Time taken: 0.41577601432800293 seconds
# Creating dataset with 2000 singular values
# Reconstruction time for k=2000: 0.0542 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2000
# Time taken: 0.3612210750579834 seconds
# Creating dataset with 2100 singular values
# Reconstruction time for k=2100: 0.0717 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2100
# Time taken: 0.39481091499328613 seconds
# Creating dataset with 2200 singular values
# Reconstruction time for k=2200: 0.0747 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2200
# Time taken: 0.3690807819366455 seconds
# Creating dataset with 2300 singular values
# Reconstruction time for k=2300: 0.0722 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2300
# Time taken: 0.4288489818572998 seconds
# Creating dataset with 2400 singular values
# Reconstruction time for k=2400: 0.0775 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2400
# Time taken: 0.3831291198730469 seconds
# Creating dataset with 2500 singular values
# Reconstruction time for k=2500: 0.1913 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2500
# Time taken: 0.643460750579834 seconds
# Creating dataset with 2600 singular values
# Reconstruction time for k=2600: 0.0960 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2600
# Time taken: 0.4792628288269043 seconds
# Creating dataset with 2700 singular values
# Reconstruction time for k=2700: 0.0974 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2700
# Time taken: 0.42335987091064453 seconds
# Creating dataset with 2800 singular values
# Reconstruction time for k=2800: 0.1230 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2800
# Time taken: 0.5445623397827148 seconds
# Creating dataset with 2900 singular values
# Reconstruction time for k=2900: 0.1125 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_2900
# Time taken: 0.522672176361084 seconds
# Creating dataset with 3000 singular values
# Reconstruction time for k=3000: 0.1162 seconds
# Saved SVD to ./CompressedDatasets/cifar/cifar10_3000
# Time taken: 0.45208287239074707 seconds
